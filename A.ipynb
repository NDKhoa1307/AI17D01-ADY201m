# %%
import requests
import json 
import pandas as pd
import random as rd

# %%
rd.seed(101)

lats = []
longs = []

for i in range(100):
    lat = (round(rd.uniform(16.09, 16.03),6))
    long = (round(rd.uniform(108.21, 108.22), 6))
    if (lat in lats) and (long in longs):
        continue
    else:
        lats.append(lat)
        longs.append(long)

print(len(lats))
print(len(longs))
# Out:
# 100
# 100

# %%
# Init the first row in df

df = pd.DataFrame()

for i in range(len(lats)):
    url = f'https://api.openweathermap.org/data/2.5/weather?lat={lats[i]}&lon={longs[i]}&appid=b85ed4c8bcfeafb299e9bafee9dab413'
    res = requests.get(url)
    data = pd.json_normalize(json.loads(res.text))
    df = pd.concat([df, data], ignore_index=True)

df
# Out:
#                                               weather      base  visibility  \
# 0   [{'id': 801, 'main': 'Clouds', 'description': ...  stations       10000
# 1   [{'id': 801, 'main': 'Clouds', 'description': ...  stations       10000
# 2   [{'id': 801, 'main': 'Clouds', 'description': ...  stations       10000
# 3   [{'id': 801, 'main': 'Clouds', 'description': ...  stations       10000
# 4   [{'id': 801, 'main': 'Clouds', 'description': ...  stations       10000
# ..                                                ...       ...         ...
# 95  [{'id': 801, 'main': 'Clouds', 'description': ...  stations       10000
# 96  [{'id': 801, 'main': 'Clouds', 'description': ...  stations       10000
# 97  [{'id': 801, 'main': 'Clouds', 'description': ...  stations       10000
# 98  [{'id': 801, 'main': 'Clouds', 'description': ...  stations       10000
# 99  [{'id': 801, 'main': 'Clouds', 'description': ...  stations       10000
#
# ...

# %%
df.to_csv('weather.csv', index = False)

# %%
newDf = pd.read_csv('./weather.csv')
newDf.head()
# Out:
#                                              weather      base  visibility  \
# 0  [{'id': 801, 'main': 'Clouds', 'description': ...  stations       10000
# 1  [{'id': 801, 'main': 'Clouds', 'description': ...  stations       10000
# 2  [{'id': 801, 'main': 'Clouds', 'description': ...  stations       10000
# 3  [{'id': 801, 'main': 'Clouds', 'description': ...  stations       10000
# 4  [{'id': 801, 'main': 'Clouds', 'description': ...  stations       10000
#
#            dt  timezone       id   name  cod  coord.lon  coord.lat  ...  \
# 0  1696488404     25200  1594018  Ap Ba  200   108.2119    16.0551  ...
# 1  1696488404     25200  1594018  Ap Ba  200   108.2192    16.0321  ...
# 2  1696488404     25200  1583992  Turan  200   108.2166    16.0620  ...
# 3  1696488405     25200  1583992  Turan  200   108.2122    16.0771  ...
# 4  1696488878     25200  1583992  Turan  200   108.2169    16.0727  ...
#
#    main.pressure  main.humidity  wind.speed  wind.deg  clouds.all  sys.type  \
# ...
